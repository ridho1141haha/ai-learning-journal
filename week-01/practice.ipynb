# %%
print("Hello AI Journey!")
# Out:
# Hello AI Journey!

# %%
nilai = [80, 75, 90, 60, 85]

# %%
def rata_rata(data):
    return sum(data) / len(data)

print(rata_rata(nilai))
# Out:
# 78.0

# %%
for n in nilai:
    if n >= 75:
        print(n, "LULUS")
    else:
        print(n, "TIDAK LULUS")
# Out:
# 80 LULUS
# 75 LULUS
# 90 LULUS
# 60 TIDAK LULUS
# 85 LULUS

# %% [markdown]
# CHALLENGE 1

# %%
nilai = [80, 75, 90, 60, 85]

def evaluasi_nilai(data):
    hasil = []
    for n in data:
        if n >= 75:
            hasil.append("LULUS")
        else:
            hasil.append("TIDAK LULUS")
    return hasil

print(evaluasi_nilai(nilai))
# Out:
# ['LULUS', 'LULUS', 'LULUS', 'TIDAK LULUS', 'LULUS']

# %% [markdown]
# CHALENGE 2 (Refactor)
# `def cek_kelulusan(data):
#  pass`

# %%
def cek_kelulusan(data):
    pass
    return ["LULUS" if n >= 75 else "TIDAK LULUS" for n in data]

# %% [markdown]
# ## DAY 2

# %%
import numpy as np

nilai = np.array([80, 75, 90, 60, 85])
print(nilai)
print(type(nilai))
# Out:
# [80 75 90 60 85]
# <class 'numpy.ndarray'>

# %%
print(nilai + 5)
# Out:
# [85 80 95 65 90]

# %%
print("Rata-rata:", np.mean(nilai))
print("Standar deviasi:", np.std(nilai))
print("Nilai max:", np.max(nilai))
print("Nilai min:", np.min(nilai))
# Out:
# Rata-rata: 78.0
# Standar deviasi: 10.295630140987
# Nilai max: 90
# Nilai min: 60

# %%
lulus = nilai[nilai >= 75]
print(lulus)
# Out:
# [80 75 90 85]

# %% [markdown]
# ## DAY 3

# %%
import pandas as pd

# %%
data = {
    "nama": ["Andi", "Budi", "Citra", "Dewi"],
    "nilai": [80, 70, 90, 60],
    "kelas": ["A", "A", "B", "B"]
}

df = pd.DataFrame(data)
df
# Out:
#     nama  nilai kelas
# 0   Andi     80     A
# 1   Budi     70     A
# 2  Citra     90     B
# 3   Dewi     60     B

# %%
df_lulus = df[df["nilai"] >= 75]
df_lulus
# Out:
#     nama  nilai kelas
# 0   Andi     80     A
# 2  Citra     90     B

# %%
df["nilai"].mean()
# Out:
# np.float64(75.0)

# %%
df.groupby("kelas")["nilai"].mean()
# Out:
# kelas
# A    75.0
# B    75.0
# Name: nilai, dtype: float64

# %%
df["status"] = df["nilai"].apply(
    lambda x: "LULUS" if x >= 75 else "TIDAK LULUS"
)

df
# Out:
#     nama  nilai kelas       status
# 0   Andi     80     A        LULUS
# 1   Budi     70     A  TIDAK LULUS
# 2  Citra     90     B        LULUS
# 3   Dewi     60     B  TIDAK LULUS

# %% [markdown]
# ## DAY 4 - Data Cleaning

# %%
import pandas as pd
import numpy as np

data_kotor = {
    "nama": ["Andi", "Budi", "Citra", "Dewi", "Andi"],
    "nilai": [80, None, 90, "enam puluh", 80],
    "kelas": ["A", "A", "B", None, "A"]
}

df = pd.DataFrame(data_kotor)
df
# Out:
#     nama       nilai kelas
# 0   Andi          80     A
# 1   Budi        None     A
# 2  Citra          90     B
# 3   Dewi  enam puluh  None
# 4   Andi          80     A

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   nama    5 non-null      object
#  1   nilai   4 non-null      object
#  2   kelas   4 non-null      object
# dtypes: object(3)
# memory usage: 252.0+ bytes

# %%
df.isnull().sum()
# Out:
# nama     0
# nilai    1
# kelas    1
# dtype: int64

# %%
df["nilai"] = pd.to_numeric(df["nilai"], errors="coerce")
df["nilai"] = df["nilai"].fillna(df["nilai"].mean())
df["kelas"] = df["kelas"].fillna("Unknown")

# %%
df = df.drop_duplicates()

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   nama    4 non-null      object
#  1   nilai   4 non-null      float64
#  2   kelas   4 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 128.0+ bytes
#     nama      nilai    kelas
# 0   Andi  80.000000        A
# 1   Budi  83.333333        A
# 2  Citra  90.000000        B
# 3   Dewi  83.333333  Unknown
